# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork21426264-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Data Visualization Lab**

# %% [markdown]
# Estimated time needed: **45 to 60** minutes

# %% [markdown]
# In this assignment you will be focusing on the visualization of data.
#
# The data set will be presented to you in the form of a RDBMS.
#
# You will have to use SQL queries to extract the data.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# *   Visualize the distribution of data.
#
# *   Visualize the relationship between two features.
#
# *   Visualize composition of data.
#
# *   Visualize comparison of data.

# %% [markdown]
# <hr>

# %% [markdown]
# ## Demo: How to work with database

# %% [markdown]
# Download database file.

# %%
# !wget https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m4_survey_data.sqlite
# Out:
# --2023-01-12 13:35:59--  https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m4_survey_data.sqlite
# Resolving cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)... 169.45.118.108
# Connecting to cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)|169.45.118.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 36679680 (35M) [application/octet-stream]
# Saving to: 'm4_survey_data.sqlite.2'
#
#      0K .......... .......... .......... .......... ..........  0% 1.11M 32s
#     50K .......... .......... .......... .......... ..........  0% 34.1M 16s
#    100K .......... .......... .......... .......... ..........  0%  728K 27s
#    150K .......... .......... .......... .......... ..........  0%  559K 36s
# ...

# %% [markdown]
# Connect to the database.

# %%
import sqlite3
conn = sqlite3.connect("m4_survey_data.sqlite.2") # open a database connection

# %% [markdown]
# Import pandas module.

# %%
import pandas as pd

# %% [markdown]
# ## Demo: How to run an sql query

# %%
# print how many rows are there in the table named 'master'
QUERY = """
SELECT COUNT(*)
FROM master
"""

# the read_sql_query runs the sql query and returns the data as a dataframe
df = pd.read_sql_query(QUERY,conn)
df.head()
# Out:
#    COUNT(*)
# 0     11398

# %% [markdown]
# ## Demo: How to list all tables

# %%
# print all the tables names in the database
QUERY = """
SELECT name as Table_Name FROM
sqlite_master WHERE
type = 'table'
"""
# the read_sql_query runs the sql query and returns the data as a dataframe
pd.read_sql_query(QUERY,conn)
# Out:
#                 Table_Name
# 0                 EduOther
# 1                  DevType
# 2                  LastInt
# 3               JobFactors
# 4                 WorkPlan
# 5            WorkChallenge
# 6       LanguageWorkedWith
# 7   LanguageDesireNextYear
# 8       DatabaseWorkedWith
# 9   DatabaseDesireNextYear
# 10      PlatformWorkedWith
# 11  PlatformDesireNextYear
# 12      WebFrameWorkedWith
# 13  WebFrameDesireNextYear
# 14      MiscTechWorkedWith
# 15  MiscTechDesireNextYear
# 16              DevEnviron
# 17              Containers
# 18               SOVisitTo
# 19            SONewContent
# 20                  Gender
# 21               Sexuality
# 22               Ethnicity
# 23                  master

# %%
QUERYH = """
SELECT *,COUNT(*) as count
FROM DevType
group by DevType
order by count
"""

# %%
dfh = pd.read_sql_query(QUERYH, conn)
dfh
# Out:
#     Respondent                                        DevType  count
# 0           62                Marketing or sales professional     61
# 1           13                            Senior executive/VP    160
# 2          129                                      Scientist    354
# 3           13                            Engineering manager    386
# 4           13                     Engineer, site reliability    449
# 5           43                    Developer, game or graphics    472
# 6           26                                Product manager    480
# 7           26                                       Educator    514
# 8          129                            Academic researcher    556
# 9           17                                        Student    766
# 10          13                       Data or business analyst    802
# 11          62  Data scientist or machine learning specialist    803
# 12          13                                 Engineer, data    832
# ...

# %% [markdown]
# ## Demo: How to run a group by query

# %%
QUERY = """
SELECT Age,COUNT(*) as count
FROM master
group by age
order by age
"""
pd.read_sql_query(QUERY,conn)
# Out:
#      Age  count
# 0    NaN    287
# 1   16.0      3
# 2   17.0      6
# 3   18.0     29
# 4   19.0     78
# 5   20.0    109
# 6   21.0    203
# 7   22.0    406
# 8   23.0    581
# 9   24.0    679
# 10  25.0    738
# 11  26.0    720
# 12  27.0    724
# 13  28.0    787
# 14  29.0    697
# 15  30.0    651
# 16  31.0    531
# 17  32.0    489
# 18  33.0    483
# 19  34.0    395
# 20  35.0    393
# 21  36.0    308
# 22  37.0    280
# 23  38.0    279
# 24  39.0    232
# 25  40.0    187
# 26  41.0    136
# 27  42.0    162
# 28  43.0    100
# 29  44.0     95
# 30  45.0     85
# 31  46.0     66
# 32  47.0     68
# 33  48.0     64
# 34  49.0     66
# 35  50.0     57
# 36  51.0     29
# 37  52.0     41
# 38  53.0     32
# 39  54.0     26
# 40  55.0     13
# 41  56.0     16
# 42  57.0     11
# 43  58.0     12
# 44  59.0     11
# 45  60.0      2
# 46  61.0     10
# 47  62.0      5
# 48  63.0      7
# 49  65.0      2
# 50  66.0      1
# 51  67.0      1
# 52  69.0      1
# 53  71.0      2
# ...

# %% [markdown]
# ## Demo: How to describe a table

# %%
table_name = 'master'  # the table you wish to describe

QUERY = """
SELECT sql FROM sqlite_master
WHERE name= '{}'
""".format(table_name)

df = pd.read_sql_query(QUERY,conn)
print(df.iat[0,0])
# Out:
# CREATE TABLE "master" (
# "index" INTEGER,
#   "Respondent" INTEGER,
#   "MainBranch" TEXT,
#   "Hobbyist" TEXT,
#   "OpenSourcer" TEXT,
#   "OpenSource" TEXT,
#   "Employment" TEXT,
#   "Country" TEXT,
#   "Student" TEXT,
#   "EdLevel" TEXT,
#   "UndergradMajor" TEXT,
#   "OrgSize" TEXT,
#   "YearsCode" TEXT,
#   "Age1stCode" TEXT,
#   "YearsCodePro" TEXT,
#   "CareerSat" TEXT,
#   "JobSat" TEXT,
#   "MgrIdiot" TEXT,
#   "MgrMoney" TEXT,
#   "MgrWant" TEXT,
#   "JobSeek" TEXT,
#   "LastHireDate" TEXT,
#   "FizzBuzz" TEXT,
#   "ResumeUpdate" TEXT,
#   "CurrencySymbol" TEXT,
#   "CurrencyDesc" TEXT,
#   "CompTotal" REAL,
#   "CompFreq" TEXT,
#   "ConvertedComp" REAL,
#   "WorkWeekHrs" REAL,
#   "WorkRemote" TEXT,
#   "WorkLoc" TEXT,
#   "ImpSyn" TEXT,
#   "CodeRev" TEXT,
#   "CodeRevHrs" REAL,
#   "UnitTests" TEXT,
#   "PurchaseHow" TEXT,
#   "PurchaseWhat" TEXT,
#   "OpSys" TEXT,
#   "BlockchainOrg" TEXT,
#   "BlockchainIs" TEXT,
#   "BetterLife" TEXT,
#   "ITperson" TEXT,
# ...

# %% [markdown]
# # Hands-on Lab

# %% [markdown]
# ## Visualizing distribution of data

# %% [markdown]
# ### Histograms

# %% [markdown]
# Plot a histogram of `ConvertedComp.`

# %%
# your code goes here

QUERY = """
SELECT * FROM master
"""
df = pd.read_sql_query(QUERY,conn)
df.hist(column='ConvertedComp')
# Out:
# array([[<AxesSubplot:title={'center':'ConvertedComp'}>]], dtype=object)

# %% [markdown]
# ### Box Plots

# %% [markdown]
# Plot a box plot of `Age.`

# %%
# your code goes here

df.boxplot(column='Age')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Visualizing relationships in data

# %% [markdown]
# ### Scatter Plots

# %% [markdown]
# import matplotlib.pyplot as plt
# %matplotlib inline
# import seaborn as snsCreate a scatter plot of `Age` and `WorkWeekHrs.`

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
# your code goes here
plot = sns.scatterplot(x='Age', y='WorkWeekHrs', data=df)

# %%
df.corr()
# Out:
#                   index  Respondent  CompTotal  ConvertedComp  WorkWeekHrs  \
# index          1.000000    0.999986  -0.013438       0.002212    -0.015365
# Respondent     0.999986    1.000000  -0.013490       0.002181    -0.015314
# CompTotal     -0.013438   -0.013490   1.000000       0.001037     0.003510
# ConvertedComp  0.002212    0.002181   0.001037       1.000000     0.021143
# WorkWeekHrs   -0.015365   -0.015314   0.003510       0.021143     1.000000
# CodeRevHrs     0.004667    0.004621   0.007063      -0.033865     0.026517
# Age            0.004177    0.004048   0.006966       0.105412     0.036517
#
#                CodeRevHrs       Age
# index            0.004667  0.004177
# Respondent       0.004621  0.004048
# CompTotal        0.007063  0.006966
# ConvertedComp   -0.033865  0.105412
# WorkWeekHrs      0.026517  0.036517
# CodeRevHrs       1.000000 -0.020498
# Age             -0.020498  1.000000

# %% [markdown]
# ### Bubble Plots

# %% [markdown]
# Create a bubble plot of `WorkWeekHrs` and `CodeRevHrs`, use `Age` column as bubble size.

# %%
sns.scatterplot(data=df, x='WorkWeekHrs', y='CodeRevHrs',size='Age', hue='Age',alpha=1, sizes=(10, 500))
plt.xlabel("X", size=16)
plt.ylabel("y", size=16)
plt.title("WorkWeekHrs and CodeRevHrs, use Age column as bubble size", size=18)
# Out:
# Text(0.5, 1.0, 'WorkWeekHrs and CodeRevHrs, use Age column as bubble size')

# %% [markdown]
# ## Visualizing composition of data

# %% [markdown]
# ### Pie Charts

# %%
DatabaseDesireNextYear

# %% [markdown]
# Create a pie chart of the top 5 databases that respondents wish to learn next year. Label the pie chart with database names. Display percentages of each database on the pie chart.

# %%
# your code goes here

QUERY1 = """
SELECT *,COUNT(*) as count
FROM DatabaseDesireNextYear
group by DatabaseDesireNextYear 
order by count(DatabaseDesireNextYear)  DESC LIMIT 5
"""


df1 = pd.read_sql_query(QUERY1,conn)
df1
# Out:
#    Respondent DatabaseDesireNextYear  count
# 0           9             PostgreSQL   4328
# 1          16                MongoDB   3649
# 2           9                  Redis   3331
# 3           4                  MySQL   3281
# 4          16          Elasticsearch   2856

# %%
QUERYX = """
SELECT *,COUNT(*) as count
FROM LanguageDesireNextYear
group by LanguageDesireNextYear 
order by count(LanguageDesireNextYear)  DESC LIMIT 5
"""

# %%
QUERYA = """
SELECT *,COUNT(*) as count
FROM LanguageWorkedWith
group by LanguageWorkedWith 
order by count(LanguageWorkedWith)  DESC LIMIT 50
"""

# %%
QUERYZ = """
SELECT *,COUNT(*) as count
FROM PlatformWorkedWith
group by PlatformWorkedWith
order by count(PlatformWorkedWith)  DESC LIMIT 10
"""

# %%
QUERYY = """
SELECT *,COUNT(*) as count
FROM DatabaseWorkedWith
group by DatabaseWorkedWith 
order by count(DatabaseWorkedWith)  DESC LIMIT 15
"""

# %%
dfz = pd.read_sql_query(QUERYZ, conn)
dfz
# Out:
#    Respondent PlatformWorkedWith  count
# 0           4              Linux   5811
# 1           4            Windows   5563
# 2           9             Docker   4378
# 3           9                AWS   3588
# 4           9              Slack   2786
# 5           9              MacOS   2718
# 6          13            Android   2693
# 7          13    Microsoft Azure   1711
# 8          17       Raspberry Pi   1614
# 9          13          WordPress   1490

# %%
dfa = pd.read_sql_query(QUERYA, conn)
dfa
# Out:
#     Respondent     LanguageWorkedWith  count
# 0            9             JavaScript   8687
# 1            9               HTML/CSS   7830
# 2            4                    SQL   7106
# 3            9  Bash/Shell/PowerShell   4642
# 4            4                 Python   4542
# 5           19                   Java   4506
# 6            4                     C#   4288
# 7            9             TypeScript   3232
# 8           13                    PHP   2913
# 9            4                    C++   1946
# 10           4                      C   1578
# 11           9                   Ruby   1149
# 12          60                     Go   1114
# 13           9              Other(s):    840
# 14          62                 Kotlin    751
# 15          26                  Swift    707
# 16          16                    VBA    628
# 17          20                      R    585
# 18          43            Objective-C    518
# 19         116                  Scala    492
# ...

# %%
dfy = pd.read_sql_query(QUERYY, conn)
dfy
# Out:
#     Respondent    DatabaseWorkedWith  count
# 0            4                 MySQL   5469
# 1           16  Microsoft SQL Server   4110
# 2            9            PostgreSQL   4097
# 3            4                SQLite   3248
# 4           16               MongoDB   3016
# 5           22                 Redis   2508
# 6           20         Elasticsearch   1954
# 7           22                Oracle   1744
# 8           20               MariaDB   1709
# 9           13              Firebase   1314
# 10           9              DynamoDB    831
# 11          44             Other(s):    728
# 12          49             Cassandra    397
# 13          13             Couchbase    250

# %%
dfx = pd.read_sql_query(QUERYX, conn)
dfx
# Out:
#    Respondent LanguageDesireNextYear  count
# 0           4             JavaScript   6630
# 1           9               HTML/CSS   5328
# 2          20                 Python   5239
# 3           4                    SQL   5012
# 4           9             TypeScript   4088

# %%
colors_list=['gold', 'yellowgreen', 'lightcoral', 'lightskyblue', 'lightgreen', 'pink']

df1.set_index('DatabaseDesireNextYear', inplace=True)
df1['count'].plot(kind='pie', figsize=(20,6), autopct='%1.1f%%', labels=None, startangle=90, shadow=True, pctdistance=1.12)

plt.legend(labels=df1.index, loc='upper right')
plt.title('Top 5 Databases Respondents wish to learn')
plt.axis('equal')
plt.show()

# %%
colors_list=['gold', 'yellowgreen', 'lightcoral', 'lightskyblue', 'lightgreen', 'pink']

dfx.set_index('LanguageDesireNextYear', inplace=True)
dfx['count'].plot(kind='pie', figsize=(20,6), autopct='%1.1f%%', labels=None, startangle=90, shadow=True, pctdistance=1.12)

plt.legend(labels=dfx.index, loc='upper right')
plt.title('Top 5 Language Respondents wish to learn')
plt.axis('equal')
plt.show()

# %%
colors_list=['gold', 'yellowgreen', 'lightcoral', 'lightskyblue', 'lightgreen', 'pink']

df1['count'].plot(kind='pie', figsize=(20,6), autopct='%1.1f%%', labels=None, startangle=90, colors=colors_list, shadow=True, pctdistance=1.12)  

#df['count'].plot(kind='pie', figsize=(20,6), autopct='%1.1f%%', labels=None, startangle=90, colors=colors_list, shadow=True, pctdistance=1.12)  


plt.legend(labels=df.index, loc='upper right')
plt.title('Top 5 Databases Respondents wish to learn')
plt.show()

# %% [markdown]
# ### Stacked Charts

# %% [markdown]
# Create a stacked chart of median `WorkWeekHrs` and `CodeRevHrs` for the age group 30 to 35.

# %%
# your code goes here

QUERY2 = """
SELECT WorkWeekHrs, CodeRevHrs, Age FROM master
WHERE Age BETWEEN 30 AND 35
"""

df3 = pd.read_sql_query(QUERY2,conn)
df4 = df3.groupby('Age').median()

df4.plot(kind='bar', figsize=(10, 6), stacked=True)

plt.title('Stacked Bar Chart of Median WorkWeekHrs and CodeRevHrs for Those Age 30 to 35')
plt.show()

# %% [markdown]
# ## Visualizing comparison of data

# %% [markdown]
# ### Line Chart

# %% [markdown]
# Plot the median `ConvertedComp` for all ages from 45 to 60.

# %%
# your code goes here

QUERY3 = """
SELECT ConvertedComp, Age FROM master
WHERE Age BETWEEN 45 AND 60
"""

df01 = pd.read_sql_query(QUERY3, conn)
df02 = df01.groupby('Age').median()

df02.plot(kind='line', figsize=(10, 6))

plt.title('ConvertedComp for 45 to 60')
plt.show()

# %%
QUERYJ = """
SELECT ConvertedComp, Age FROM master
WHERE Age BETWEEN 25 AND 30
"""

dfj1 = pd.read_sql_query(QUERYJ, conn)
dfj2 = dfj1.groupby('Age').median()

dfj2.plot(kind='line', figsize=(10, 6))

plt.title('ConvertedComp for 25 to 30')
plt.show()

# %% [markdown]
# ### Bar Chart

# %% [markdown]
# Create a horizontal bar chart using column `MainBranch.`

# %%
# your code goes here

QUERY4 = """
SELECT MainBranch, COUNT(*) as MainBranch
FROM master
"""

ff1 = pd.read_sql_query(QUERY4, conn)

ff1.plot(kind='barh', figsize=(10, 6))

plt.title('ConvertedComp for 45 to 60')
plt.show()

# %% [markdown]
# Close the database connection.

# %%
conn.close()

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By        | Change Description                 |
# | ----------------- | ------- | ----------------- | ---------------------------------- |
# | 2020-10-17        | 0.1     | Ramesh Sannareddy | Created initial version of the lab |

# %% [markdown]
# Copyright © 2020 IBM Corporation. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork21426264-2022-01-01&cm_mmc=Email_Newsletter-\_-Developer_Ed%2BTech-\_-WW_WW-\_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ).
